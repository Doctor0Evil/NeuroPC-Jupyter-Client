# %%
from pathlib import Path
from neuropc_jupyter_client import NeuroPCConfig, NeuroFSIndex, ShardsClient

cfg = NeuroPCConfig.from_repo_root("..")
index = NeuroFSIndex.load(cfg.neurofs_index)
client = ShardsClient(index)
df = client.load_biosession_metrics()
df.head()
